# %%
import requests
import json
import pickle

# %%
base_url = "https://archives.jacobspillow.org/admin/"

with open('login', 'r') as f:
    lines = f.readlines()
    username = lines[0].strip()
    password = lines[1].strip()

# %% [markdown]
# Logging in with credentials in order to retrieve information

# %%
# Login query
query = """
query {
  login(username: "%s", password: "%s") {
    jwt
    refresh
    user {
      id
      fname
      lname
      email
    }
  }
}
""" % (username, password)

# Send login request

headers = {"Content-Type": "application/json", "Accept": "application/json"}
data = json.dumps({"query": query})
response = requests.post(f"{base_url}/service/Auth", headers=headers, data=data)

# Check for successful response
if response.status_code == 200:
   data = json.loads(response.text)
   jwt = data["data"]["login"]["jwt"]
else:
  print(f"Error logging in: {response.text}")

# %%
def find_all_entities(entities_types):
  """
  Searches for entities of specified types and returns their preferred labels.

  Args:
      entities_types (str): Comma-separated string of entity types to search for.

  Returns:
      list: List of entity preferred labels (display names).
  """

  query_browse_entity = f"""
  query {{
    search(
      table: "ca_entities",
      search: "a",
      restrictToTypes: ["{entities_types}"],
      bundles: ["ca_entities.preferred_labels.displayname"],
      start: 0
    ) {{
      result {{
        id,
        table,
        idno,
        bundles {{
          code,
          name,
          dataType,
          values {{
            value,
            locale
          }}
        }}
      }}
    }}
  }}
  """

  headers = {
      "Content-Type": "application/json",
      "Accept": "application/json",
      "Authorization": f"Bearer {jwt}"
  }

  data = json.dumps({"query": query_browse_entity})
  response = requests.post(f"{base_url}/service/Search", headers=headers, data=data)

  if response.status_code == 200:
    try:
      parsed_data = json.loads(response.content)
      tables = parsed_data.get("data", {}).get("search", {}).get("result", [])
      print(tables)
      return [table["bundles"][0]["values"][0]["value"] for table in tables]
    except (KeyError, json.JSONDecodeError) as e:
      print(f"Error parsing response: {e}")
      return []  # Handle parsing errors gracefully

  else:
    print(f"Error logging in: {response.text}")

  return []  # Explicitly return empty list on errors for clarity

# %%
find_all_entities("individual")
# Out:
# [{'id': 27024, 'table': 'ca_entities', 'idno': 'A. Epstein', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'A. Epstein', 'locale': 'en_US'}]}]}, {'id': 27103, 'table': 'ca_entities', 'idno': 'A. John Geraci', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'A. John Geraci', 'locale': 'en_US'}]}]}, {'id': 51, 'table': 'ca_entities', 'idno': 'Reeves, John A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Reeves, John A.', 'locale': 'en_US'}]}]}, {'id': 60, 'table': 'ca_entities', 'idno': 'Gates, Alice A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Gates, Alice A.', 'locale': 'en_US'}]}]}, {'id': 75, 'table': 'ca_entities', 'idno': 'Nagler, A. M.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Nagler, A. M.', 'locale': 'en_US'}]}]}, {'id': 123, 'table': 'ca_entities', 'idno': 'Twysden, A. E.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Twysden, A. E.', 'locale': 'en_US'}]}]}, {'id': 127, 'table': 'ca_entities', 'idno': 'Hall, A. George', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Hall, A. George', 'locale': 'en_US'}]}]}, {'id': 202, 'table': 'ca_entities', 'idno': 'Franks, A. H.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Franks, A. H.', 'locale': 'en_US'}]}]}, {'id': 355, 'table': 'ca_entities', 'idno': 'Palme, A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Palme, A.', 'locale': 'en_US'}]}]}, {'id': 370, 'table': 'ca_entities', 'idno': 'Long, Richard A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Richard A. Long', 'locale': 'en_US'}]}]}, {'id': 405, 'table': 'ca_entities', 'idno': 'Flint, Janet A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Flint, Janet A.', 'locale': 'en_US'}]}]}, {'id': 509, 'table': 'ca_entities', 'idno': 'Phillips, Patricia A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Phillips, Patricia A.', 'locale': 'en_US'}]}]}, {'id': 544, 'table': 'ca_entities', 'idno': 'Smith, Ralph A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Smith, Ralph A.', 'locale': 'en_US'}]}]}, {'id': 554, 'table': 'ca_entities', 'idno': 'Harris, Jane A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Harris, Jane A.', 'locale': 'en_US'}]}]}, {'id': 566, 'table': 'ca_entities', 'idno': 'Ewing, William A', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Ewing, William A', 'locale': 'en_US'}]}]}, {'id': 594, 'table': 'ca_entities', 'idno': 'Meerloo, Joost A. M.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Joost A. M. Meerloo', 'locale': 'en_US'}]}]}, {'id': 640, 'table': 'ca_entities', 'idno': 'Rowe, Patricia A.', 'bundles': [{'code': 'ca_entities.preferred_labels.displayname', 'name': 'Display name', 'dataType': 'Text', 'values': [{'value': 'Rowe, Patricia A.', 'locale': 'en_US ...
# ['A. Epstein',
#  'A. John Geraci',
#  'Reeves, John A.',
#  'Gates, Alice A.',
#  'Nagler, A. M.',
#  'Twysden, A. E.',
#  'Hall, A. George',
#  'Franks, A. H.',
#  'Palme, A.',
#  'Richard A. Long',
#  'Flint, Janet A.',
#  'Phillips, Patricia A.',
#  'Smith, Ralph A.',
#  'Harris, Jane A.',
#  'Ewing, William A',
#  'Joost A. M. Meerloo',
#  'Rowe, Patricia A.',
#  'Mansfield, Evelyn A.',
#  'Papageorgiou, C. A.',
#  'A. J. Pischl',
#  'Zorn, Friedrich A.',
#  'Clark, VeVe A.',
#  'Logan, Gene A.',
#  'Coton, A. V.',
#  'Westrup, J. A.',
#  'Bernard A. Drew',
#  'Thurston, H. A.',
#  'Loeffler, Pauline A.',
#  'Wilson, A. E.',
#  'Steiner, George A.',
#  'Pokrovsky, Boris A.',
#  'David, Martin A.',
#  'A. E. Johnson',
#  'W. A. Propert',
#  'Miller, Kamae A., ed.',
#  'Eyes Of A Blue Dog Dance Theater',
#  'Camille A. Brown',
#  'Samuel A. Miller',
#  'William A. Ewing',
#  'Susan A. Manning',
#  'Timothy A. Fischer',
#  'George A. Lawrence',
#  'Charles A Doran',
#  'Jennifer A. Cooper',
#  'A. K. Salim',
#  'A. Pla Alvarez',
#  'A. Roger Smith',
#  'A. Beriot',
#  'A. Leroy',
#  'Arnold Dreyblatt/Bang on a Can',
#  'A Cappella',
#  'Mirjam ter Linden Rafael A. Hernandez III',
#  'Lights in a Fat City',
#  'Light in a Fat City',
#  'A. Cordova',
#  'A. Christina Giannini',
#  "Eva Bust A' Move",
#  'Esailama G. A. Diouf',
#  'A. J. Pietrantone',
#  'Carlos R. A. Jones',
#  'William A. Ervin Jr.',
#  'A. R. Rahman',
#  'A Winged Victory For The Sullen',
#  'A. G. Storozhuk',
#  'Katelyn A. Sanchez',
#  'Kwame A. Ross',
#  'Althea Unrath',
#  'James A. Smith',
#  'Robert A. Fredericks',
#  'Martin A. Medellin',
#  'Kiera A. Connors',
#  'Rodney A. Brown',
#  'Callye A. Robinson',
#  'OluShola A. Cole',
#  'Anila A. Mazhary',
#  'Jalila A. Bell',
#  'Jill A. Locke',
#  'Laurel A. Zaleski',
#  'Cartier A. Williams',
#  'Calvin A. Rollins II',
#  'Mallory A. Mehaffey',
#  'Jose A. Carrillo',
#  'David Lang &amp; Bang on a Can',
#  'James A. Frazier',
#  'Rafael A. Hernandez III',
#  'John A. James',
#  'Jytte A. Brooks',
#  'Lori A. Landers',
#  'Nikki A. Wilson',
#  'D. A. Pennebaker',
#  'Danielle A. Smith',
#  'Keith A. Thompson',
#  'Jennifer A. Phillips',
#  'Karima A. Miller',
#  'Julie A. Strandberg',
#  'David A. Peden',
#  'Demetrius A. Klein',
#  'Valerie A. Winborne',
#  'Bennet A. Crocker',
#  'Julie A. Kingman',
#  'Chris A. Bence',
#  'Amith A. Chandrashaker',
#  'Hyon A Lee',
#  'Lloyd A. Boyd III',
#  'Patricia A. Keeler ',
#  'Constance A. Schrader',
#  'Lenai A. Wilkerson',
#  'Kathy A. Perkins',
#  'Alexandra A. Murillo',
#  'Roberta A. Lucas',
#  'Rosemarie A. Roberts',
#  'Debra A. Levinson',
#  'Tamisha A. Guy',
#  'Albert A. Johnstone',
#  'Judith A. Gray',
#  'Nassau County Museum of FIne Art',
#  'Aubrey Hitchins',
#  'Alonza Rivera',
#  'Alfred Schnittke',
#  'Arthur Saint Leon',
#  'Andonis Foniadakis',
#  'Andres Segovia',
#  'Arthur Foote',
#  'Alexandra Groff',
#  'Alex Karigan Farrior',
#  'Aurélien Peillux',
#  'North Carolina School of the Arts',
#  'A&amp;A Kamerabild',
#  'Abraham Walkowitz',
#  'Albert Kane',
#  'Anne Holm',
#  'Gena Mann',
#  'Gena Rho',
#  'Ted Shawn',
#  'Barton Mumaw',
#  'Chet Walker',
#  'Lotte Goslar',
#  'Wilbur McCormack',
#  'Frank Overlees',
#  'Jess Meeker',
#  'Fred Hearn',
#  'Dennis Landers',
#  'Foster Fitz-Simons',
#  'Myra Kinch',
#  'Maura Keefe',
#  'Ruth St. Denis',
#  'Mark Morris',
#  'Norman Walker',
#  'William Howell',
#  'Ned Coupland',
#  'Victoria Marks',
#  'John Fischer',
#  'June Omura',
#  'Ruth Davidson',
#  'Timothy Buckley',
#  'Johann Sebastian Bach',
#  'Frank Delmar',
#  'John Delmar',
#  'Hernando Cortez',
#  'Guillermo Resto',
#  'Tina Fehlandt',
#  'William Wagner',
#  'Eiko Otake',
#  'Charles Weidman',
#  'Melinda Sullivan',
#  'Joe Bowie',
#  'Mireille Radwan-Dana',
#  'Kraig Patterson',
#  'Claude Debussy',
#  'Norton Owen',
#  'Davon Suttles',
#  'Iva Kitchell',
#  'Michael Moschen',
#  'Jason Samuels Smith',
#  'Dana Moore',
#  'Dan Joyce',
#  'Joe Chvala',
#  'Clayton Schanilec',
#  'Bill Hastings',
#  'La Meri',
#  'Peter Di Falco',
#  'Jonathan Phelps',
#  'Bill T. Jones',
#  'Moses Pendleton',
#  'Soledad Barrio',
#  'Michael Davis',
#  'Donnetta Jackson',
#  'Andrew Carr',
#  'DJ D9-3',
#  'Imania Detry',
#  'Annie Hanauer',
#  'Wendy Whelan',
#  'Ruth Page',
#  'David Parsons',
#  'Bebe Miller',
#  'Katherine Litz',
#  'Shirley Jensen',
#  'Shannon Lewis',
#  'Ronald K. Brown',
#  'Claire Jacob-Zysman',
#  'Andrew Fitch',
#  'Sarah Reich',
#  'Daniel Charon',
#  'Chloe Arnold',
#  'Lee Howard',
#  'Bryan Arias',
#  'Jonathan Riedel',
#  'Francisco Ruvalcaba',
#  'Marjorie Folkman',
#  'Paloma McGregor',
#  'Rebecca Nordstrom',
#  'Billbob Brown',
#  'Heather Rutka',
#  'Liz Flynn',
#  'Catherine Meredith',
#  'J. Alexis Thury',
#  'Rachael Venner',
#  'Rod Atcheynum',
#  'Leslie Barichello',
#  'Jason Daniels',
#  'Bronson Haywahe',
#  'Kevin Haywahe',
#  'Georgena Jones',
#  'Isaac Lehi',
#  'Marc Meekis',
#  'Dallas Morrison',
#  'Lisa Odjig-Fisher',
#  'Elizabeth Olney',
#  'Darrell Paskemin',
#  'Sancha Paskemin',
#  'Marty Pinnecoose',
#  'Dawn Russell',
#  'Dmitri Seth',
#  'Eddie Swimmer',
#  'Morgan Tosse',
#  'Shawn Yazzie',
#  'Victoria Lundell',
#  'Megan Williams',
#  'Brian Sostek',
#  'Barbara Canner',
#  'Lydia Charaf',
#  'Lauren F. Helfand',
#  'Kay Wendt LeSota',
#  'Linda Lenart',
#  'Christy Munch',
#  'Bryan Saner',
#  'Jeanette Welp',
#  "John Kaha'i Topolinski",
#  'Kawewehilani Correia',
#  'Hoakalei Kamauu',
#  'Hoakalei Hina Kamauoha',
#  'Wade Baker',
#  'Joe Bellanger',
#  'Rudy Bob',
#  'Lavina Colwash',
#  'Chester Mahooty',
#  'Arlie Neskahi',
#  'Norman Roach',
#  'Danell Tailfeathers',
#  'Andy Vasquez',
#  "Kawaiokawa'awa'a Akim",
#  'Nanialii Serrao',
#  'Dickie Mosier',
#  'Anthony Lenchanko',
#  'Keoni Dupont',
#  'Romona Roach',
#  'Dwight White Buffalo',
#  'Fernando Alonso',
#  'Manuel Galea',
#  'Philip Glass',
#  'Edvard Grieg',
#  'John Cage',
#  'Thuli Dumakude',
#  'Hugo Brument',
#  'Jane Sherman',
#  'Paul Taylor',
#  'Lois Smith',
#  'Grant Strate',
#  'Zoe Scofield',
#  'Starinah Dixon',
#  'Case Prime',
#  'Sterling Harris',
#  'Bril Barrett',
#  'Ivy Anderson',
#  'Kelsey Fields',
#  'William Wims',
#  'Caleb Jackson',
#  'Eddie Martin',
#  'Wesley Stewart',
#  'Naomi Kinslow',
#  'Deborah Lennie',
#  'Salva de María',
#  'Manuel Gago',
#  'Emilio Florido',
#  'Jaime Shannon',
#  'Doris Humphrey',
#  'Teodoro Morca',
#  'Carmen de Lavallade',
#  'Jean Cebron',
#  'Ruth Mata',
#  'Eugene Hari',
#  'Kathleen Carlin',
#  'Martine van Hamel',
#  'Cathy McCann',
#  'Peggy Baker',
#  'Keith Sabado',
#  'Caleb Teicher',
#  'Thaddeus Davis',
#  'Fei-fei Wu',
#  'Julie Fiorenza',
#  'Brian Brooks',
#  'Dan Gross',
#  'Nathan Trice',
#  'Ric Ryder',
#  'Maurya Kerr',
#  'Emanuel Abruzzo',
#  'Luke Hickey',
#  'Brian Melick',
#  'Jomar Mesquita',
#  'Matthew Branham',
#  'Leonides D. Arpon',
#  'William Isaac',
#  'Mei-Hua Wang',
#  'Natalie Desch',
#  'Charlton Boyd',
#  'Michael Trusnovec',
#  'Brian Carey Chung',
#  'Megumi Eda',
#  'Theresa Ruth Howard',
#  'Surupa Sen',
#  'Kristin Taylor',
#  "Roxane D'Orleans Juste",
#  'Bradon McDonald',
#  'Rhea Patterson',
#  'Tiffany Jackson',
#  'Nigel R. Campbell',
#  'Jeremy Clayton',
#  'Shawn Gannon',
#  'Meg Van Dyck',
#  'Serena Hadsell',
#  'Ann Sorvino',
#  'Lisa Travis',
#  'Jeanine Durning',
#  'Colin Jacobsen',
#  'Cheng-Chieh Yu',
#  'Mary Ford',
#  'Robert Regala',
#  'Shannon Mulahy',
#  'Karla Grotting',
#  'Kris Heruth',
#  'Jan Naegele-Campbell',
#  'Brent Edwards',
#  'Calla Jo',
#  'Tara Susman',
#  'Susanne Liebich',
#  'Dawn Meltzer',
#  'Myriam Herve-Gil',
#  'Beth Soll',
#  'Shelly Cohn',
#  'Sharon Hershfield',
#  'Zippora Karz',
#  'Paul Boos',
#  'Larissa Velez-Jackson',
#  'Jon Velez-Jackson',
#  'Andrés Correa',
#  'David Van Tieghem',
#  'Linda Chow',
#  'Igor Stravinsky',
#  'Benjamin Britten',
#  'Nina Simone',
#  'Ludwig van Beethoven',
#  'Wolfgang Amadeus Mozart',
#  'Duke Ellington',
#  'Johannes Brahms',
#  'Maurice Ravel',
#  'Bela Bartok',
#  'Frederic Chopin',
#  'George Balanchine',
#  'Irene Rodríguez',
#  'George Zoritch',
#  'Merce Cunningham',
#  'Frederic Franklin',
#  'Geoffrey Holder',
#  'Dale Lefler',
#  'Loren Hightower',
#  'Flemming Flindt',
#  'Remy Charlip',
#  'Larry Humphries',
#  'Mary Cochran',
#  'Herve Koubi',
#  'Apo Ashjian',
#  'Pat Taylor',
#  'Hagop Ashjian',
#  'Marge Champion',
#  'Anthony Bocconi',
#  'Martin Santangelo',
#  'Cynthia Quinn',
#  'Emerson and Jayne',
#  'Gower Champion',
#  'Teddy Fatscher',
#  'Mark London',
#  'Melanie George',
#  'Jared Bogart',
#  'Sarah Lamb',
#  'Lukas B. Brændsrød',
#  'Joseph Sissens',
#  'Viola Pantuso',
#  'Leo Dixon',
#  'Issey Miyake',
#  'Chris Wilkinson',
#  'Silja Gruner',
#  'Laila White',
#  'Giuseppe Comuniello',
#  'Valentina Golfieri',
#  'Marzio Picchetti',
#  'Blake Bellanger',
#  'Nathaniel Davis',
#  'Phoebe Katzin',
#  'Pablo Fraile',
#  'Jesús Helmo',
#  'Paula Bolaños',
#  'Stella Goldin García',
#  'Alexa Ratini',
#  'Alishanee Chafe-Hearmon',
#  'Salva Cortés',
#  'John Butler',
#  'Emily Schoen',
#  'Garth Fagan',
#  'Brenda Way',
#  'Ricardo Graziano',
#  'Mariana Oliveira',
#  'Ralph Lemon',
#  'Wendy Perron',
#  'Suki Schorer',
#  'Donna McKechnie',
#  'Art Bridgman',
#  'Valerie Bettis',
#  'Betty Jones',
#  'Charles Tate',
#  'John Michael Schert',
#  'Ernestine Day',
#  'Ann Douglas',
#  'John Schubert',
#  'Conrad Ludlow',
#  'Donlin Foreman',
#  'Charissa Barton',
#  'Eric Beauchesne',
#  'Francesca Harper',
#  'Glen Tetley',
#  'Maria Cheng',
#  'Wilbus McCormack',
#  'Harry Coble',
#  'Sam Steen',
#  'Grace Graff',
#  'Kurt Graff',
#  'Estelle Nadel',
#  'Peter Hamilton',
#  'Nadine Gae',
#  'Saida Gerrard',
#  'Betty Osgood',
#  'Boyd Seghers',
#  'Felisa Conde',
#  'Betts Lee',
#  'Karl Moris',
#  'Robert Herget',
#  'David Tihmar',
#  'Marvin Krauter',
#  'Mia Slavenska',
#  'Emy St. Just',
#  'Zebra Nevins',
#  'Gunnar Spencer',
#  'Lillian Jarvis',
#  'Judie Colpman',
#  'Colleen Kenney',
#  'Olivia Wyatt',
#  'Myrna Aaron',
#  'Margaret Morris',
#  'Christiane Bering',
#  'Virginia Johnson',
#  'Tilly Abbe',
#  'Bene Arnold',
#  'Gloria Cancilla',
#  'Fiona Fuerstner',
#  'Sue Loyd',
#  'Rocky Drew',
#  'Louise Lawler',
#  'Glen Chadwick',
#  'Julian Herrin',
#  'Alonso Castro',
#  'Al Huang',
#  'Sylvia Wellman',
#  'Gail Donaldson',
#  'Suzanne Hywel',
#  'Jose Barrera',
#  'Tony Catanzaro',
#  'Michael Uthoff',
#  'Alonso Cano',
#  'Gary Chryst',
#  'Carla Maxwell',
#  'Jo-Ann Bruggemann',
#  'Bob Bowyer',
#  'Judith Gosnell',
#  'John Simone',
#  'Sara Rudner',
#  'James Dunne',
#  'Donna Cowen',
#  'Mary Ann Neu',
#  'Alyce Bochette',
#  'Scott Bryant',
#  'Marianne Claire',
#  'Howard Fine',
#  'Gene French',
#  'Charles Haack',
#  'Ronald Johnson',
#  'Fred McKitrick',
#  'Janis Roswick',
#  'Debra Weiss',
#  'Richard Fields',
#  'Erica Drew',
#  'Jamie Bishton',
#  'Emmanuele Phuon',
#  'David Porter',
#  'Ruthlyn Salomons',
#  'Vernon Scott',
#  'Celeste Miller',
#  'Rita Donahue',
#  'Michelle Yard',
#  'Daniel Ulbricht',
#  'Chanel DaSilva',
#  'Travis Walker',
#  'Ashley Werhun',
#  'Jennifer Weber',
#  'Kaena Ahern',
#  'Ashley Baszto',
#  'Alberto Blanco',
#  'Jesse Campbell',
#  'Connor Scott Cohen',
#  'Rachelle di Stasio',
#  'Adrianna Duda',
#  'Darion Flores',
#  'Christian Griggs-Drane',
#  'Alex Hathaway',
#  'Yoka Hirayama',
#  'Lexi Johnston',
#  'Emilia Karmitsa',
#  'Rachel Kivlighan',
#  'Erin McNeill',
#  'Xavier Reigneau-Hawke',
#  'Eoin Robinson',
#  'Imani I. Sailers',
#  'Oliver Marcus Starpov',
#  'Jack Thomas',
#  'Ryan Vetter',
#  'Reagan Wise',
#  'Wei Wei',
#  'Yung-Li Chen',
#  'John Heginbotham',
#  'Nana Shi',
#  'Shen Jie',
#  'Mark Leavitt',
#  'Macy Sullivan',
#  'Maiko Baba',
#  'Naysh Fox',
#  'Malcolm Gets',
#  'Sarah Haarmann',
#  'Kana Kimura',
#  'Laura Mead',
#  'Guzman Rosado',
#  '"J.R." Glover',
#  'Charla Genn',
#  'James Baker',
#  'Kyla Barkin',
#  'Kristen Foote',
#  'Stefanie Weber',
#  'Bruno Argenta',
#  'Marie Klaiber',
#  'Matt Pardo',
#  'Sara Senecal',
#  'Robert Shane',
#  'Laura Teeter',
#  'Jennifer Yackel',
#  'Johnny Vorsteg',
#  'David Neumann',
#  'Sarah Zehnder',
#  'Tymberly Canale',
#  'Molly Hickok',
#  'Frankie Martinez',
#  'Joelle Bouvier',
#  'Nico Brown',
#  'Teri Ralston',
#  'Bergen Wheeler',
#  'Alexandra Johnson',
#  'Erin Brennan',
#  'Isabel Gotzkowsky',
#  'Jermaine Spivey',
#  'Emily Holohan',
#  'Hannah Tobias',
#  'Rowan Willigan',
#  'Christy Kowalsky',
#  'Leighann Kowalsky',
#  'Belen Maya',
#  'Rocio Molina',
#  'Stacey Calvert',
#  'Jacqueline Caputo',
#  'Terri Klausner',
#  'Leyland Simmons',
#  'Roderick Jackson',
#  'Nina Watt',
#  'Winston Dynamite Brown',
#  'Geordie Graham',
#  'George Steares',
#  'Pauline Lawrence',
#  'Mary Howry',
#  'Stephen Bogardus',
#  'Myrna Packer',
#  'Robert Een',
#  'Ken Field',
#  'Robert Moses',
#  'Lori Brungard',
#  'Amber Darragh',
#  'David Leventhal',
#  'Allison Fippinger',
#  'Bernard Brown',
#  'Liz Lea',
#  'Karama Butler',
#  'William Briscoe',
#  'Tina Finkelman',
#  'Lesley Kennedy',
#  'Doug Letheren',
#  'Raphaël Boumaïla',
#  'Kurt Douglas',
#  'Ryoko Kudo',
#  'Brenna Monroe-Cook',
#  'Erin Pride',
#  'Luke Willis',
#  'Yin-Ling Lin',
#  'Banning Roberts',
#  'Anthony Smith',
#  'Christal Brown',
#  'Shani Collins',
#  'Kelly Zen-Yie Tsai',
#  'Arcell Cabuag',
#  'Danny Buraczeski',
#  'Stacy Dawson',
#  'Adam Hougland',
#  'Matthew Rose',
#  'Magali Brito',
#  'Jazz Dillingham',
#  'Jamie Duggan',
#  'Alex Frei',
#  'Susana Garcia',
#  'Charis Haines',
#  'Travis Khan',
#  'Molly Knochel',
#  'Samantha Lazzaro',
#  'Catherine Elizabeth Loomis',
#  'Marc Macaranas',
#  'Alanna Morris',
#  'Danielle Ohn',
#  'Cheryl Petersen',
#  'Autumn Proctor',
#  'Riccardo Vitello',
#  'Tanairi Sade Vasquez',
#  'Andre M. Zachery',
#  'Kimmie Zicherman',
#  'Dolores Lagdameo',
#  'Roxanne Lyst',
#  'Ebony Ruffin',
#  'Michelle Smith',
#  'Marty Beller',
#  'Gregory Dawson',
#  'Xavier Ferla',
#  'Lauren Porter',
#  'Chiharu Shibata',
#  'Katie Rayle',
#  'Pigi Stamouli',
#  'Cynthia Hopkins',
#  'Michael Donaghy',
#  'Dede LaBarre',
#  'Robert La Fosse',
#  'Diana Laurenson',
#  'Solange Sandy',
#  'Joe Goode',
#  'Apollo Burnett',
#  'Alexandra Buss',
#  'Julieta Carbonel',
#  'Vibecke Dahle',
#  'Jonathan Day',
#  'Ryan Donovan',
#  'Eric Gay',
#  'Natalie Greene',
#  'Siri Holmen',
#  'Irene Kirmizaki',
#  'Ashley Knight',
#  'Monica Kreutzmann',
#  'Raul Macherro',
#  'Natalia Morales',
#  'Natalie Penn',
#  'Johary Ramos',
#  'Courtney Smith',
#  'Leslie Spanitz',
#  'Karen Swierski',
#  'Dionysios Tsaftaridis',
#  'Saralyn Ward',
#  'Ana Romero',
#  'Alejandra Ramirez',
#  'Noe Barroso',
#  'Elizabeth Anna Hall',
#  'Kristin Tovson',
#  'Joe Shepard',
#  'Peter Melville',
#  'Wen Shuan Yang',
#  'Melanie Henderson',
#  'Alex Ketley',
#  'Summer Lee Rhatigan',
#  'Christian Burns',
#  'Luis Torres',
#  'Marina Hotchkiss',
#  'Debra Rose',
#  'Eva Marin',
#  'Irene Hultman',
#  'Susan Rose',
#  'Maris Wolff',
#  'Livia D. Vanaver',
#  'Elizabeth Koeppen',
#  'Jaime Martinez',
#  'Andrew Asnes',
#  'Dana Reitz',
#  'Carlos Orta',
#  'Gail Gilbert',
#  'Rebecca Stein',
#  'Carl Flink',
#  'Pamala Jones-Malave',
#  'Gary Masters',
#  'Emilie Plauche',
#  'Alexandra Proia',
#  'Molly Daly',
#  'Marianne Moore',
#  'Molly Smolen',
#  'David Pittenger',
#  'Ellis Wood',
#  'Mark Black',
#  'Jennifer Findlay',
#  'Bill Melton',
#  'Walfred Swanson',
#  'Steve Paul',
#  'Patricia Kenny',
#  'Christopher Kirby',
#  'Kristin Lathrop',
#  'Sarah Nachbauer',
#  'Marie Taylor',
#  'Valerie Laurin',
#  'Tamara Nachbauer',
#  'Tonya Madden',
#  'Christine van Dyke',
#  'Jennie de Forest',
#  'Allyson Olewnik',
#  'Cameron Allshouse',
#  'Christine Brennan',
#  'Ashley Keyes',
#  'Kate Frissel',
#  'Katie Bercury',
#  'Katie Boino',
#  'Scott Whipple',
#  'Lilla Arnaboldi',
#  'John Evans',
#  'Marie-Agnes Arlot',
#  'Sylvie Schoch',
#  'Juliette Vezat',
#  'Renee Lemieux',
#  'Earnie Stevenson',
#  'Alexander Kaschock',
#  'Petra Adelfang',
#  'Samuel Bennett',
#  'Patti Eylar',
#  'Mark Ward',
#  'Suzy Strain',
#  'Troy Hoggard',
#  'Hellmut Gottschild',
#  'Regis Obadia',
#  'Karl Kubik',
#  'Elizabeth Caron',
#  'Valerie Anderson',
#  'Philip Karg',
#  'Jeffry Pike',
#  'Mikke Castro',
#  'Vukan Belojevic',
#  'Julia Feeley',
#  'Emily Bernet',
#  'Jacob Jonas',
#  'Reggie (Regg Roc) Gray',
#  'Spenser Theberge',
#  'Drew Minard',
#  'Jenni Poole',
#  'Taylor Rodman',
#  'Logan Frances Kruger',
#  'James "Banks" Davis',
#  'Rafael "Droid" Burgos',
#  'Quamaine "Karnage" Daniels',
#  'Andrew Winans',
#  'Kim Lusk',
#  'Letwan “Smooth” Ricks',
#  'Yohan García',
#  'Simon Schäfer',
#  'Keisha Clark-Booth',
#  'Justin Edmonson',
#  'Tashara Gavin-Moorehead',
#  'Latrice Postell',
#  'Shari Washington Rhone',
#  'Chris Smith',
#  'Laura Ann Smyth',
#  'Erin McElhone',
#  'Mina Nishimura',
#  'David Guzman',
#  'Emma Rose Brown',
#  'Stuart B Meyers',
#  'Jennifer Tipton',
#  'Alan Brodie',
#  'Julie E. Ballard',
#  'Sarah Fornace',
#  'Julia Miller',
#  'Kyle Vegter',
#  'Grant Richards',
#  'Harvey Brown',
#  'Marshall Taylor',
#  'Frederick Bristol',
#  'John Convertino',
#  'Reynier Llorente',
#  'Doug Hinrichs',
#  'Val Jeanty',
#  'Cat Ashley',
#  'Christopher R. Wilson',
#  'Malcolm-x Betts',
#  'Mary Read',
#  'Shizu Homma',
#  'Irene López',
#  'Santo Loquasto',
#  'Maria Torres',
#  'Steve Reich',
#  'Olafur Arnalds',
#  'Gustav Mahler',
#  'Peter Ilich Tchaikovsky',
#  'Stephen Sondheim',
#  'Dan Siegler',
#  'Richard Strauss',
#  'Clifford Vaughan',
#  'George Frederic Handel',
#  'Scott Marshall',
#  'Michael Leonhart',
#  'Michael Sansonia',
#  'The Social Climbers',
#  'Manuel de Falla',
#  'Michael Manson',
#  "Christopher d'Amboise",
#  'August Bournonville',
#  'Liz Lerman',
#  'Lar Lubovitch',
#  'José Limón',
#  'Jack Cole',
#  'Jerome Robbins',
#  'Jiri Kylian',
#  'Jessica Lang',
#  'Kyle Abraham',
#  'Andy Blankenbuehler',
#  'Annie-B Parson',
#  'Joshua Manculich',
#  'Robyn Mineko Williams',
#  'Rennie Harris',
#  'Pam Tanowitz',
#  'Dwight Rhoden',
#  'Augusto Soledad',
#  'Katherine Profeta',
#  'Marc Bogaerts',
#  'Maurice Bejart',
#  'Suzanne Carbonneau',
#  'Ella Baff',
#  'Peter Chu',
#  'Andrea Angelica Rodriguez',
#  'Charles Eugene Scheland',
#  'R. Sumi Matsumoto',
#  'Jeremy Villas',
#  'Noah Hardy',
#  'Heidi Boisvert',
#  'Maggie Schoenfeld',
#  'Quinton Brooks',
#  'Natalia Burns',
#  'Cayce Cavett',
#  'Madeline Diehl',
#  'Shaiya Fand',
#  'Alexandria Heath',
#  'Alex Marxer',
#  'Maya Milić',
#  'Mikaela Milić',
#  'Troy Monger-Levin',
#  'María G. Pérez Quintero',
#  'Lily Peta',
#  'Eleanor Prince',
#  'Hailey Stinchcomb',
#  'Mingus de Swaan',
#  'Ashton Wise',
#  'Grace Hankins',
#  'Thomas Ng',
#  'Oliver Buzzard',
#  'Caroline Frederick',
#  'Kate Ross',
#  'Sally Rhee',
#  'Chloe Hughlett',
#  'Eliza Vecchiarelli',
#  'Kris Gooding',
#  'Marisa Davis',
#  "Katelyn Connor 'KC' Lin",
#  'Clara Kennedy',
#  'Reagan Mulvey',
#  'Natalia Nikitin',
#  'Audrey Webb',
#  'James Alexander',
#  'Jay Armstrong',
#  'Sydney Coffey',
#  'Liz Doubrovsky',
#  'Jessica Wright',
#  'Amanda Bacallao',
#  'Haley Beck',
#  'Tyler Chang',
#  'Isabelle Evans',
#  'Mason Evans',
#  'Emma Galvin',
#  'Dante Gonzalez',
#  'Kaiya Hara-Lee',
#  'Holden Kunowski',
#  'Avery Lau',
#  'Arayah Lyte',
#  'Garris Munoz',
#  'Max Nelson-Steinhoff',
#  'Kasey Orava',
#  'Ali-asha Polson',
#  'Jalyn Postadan',
#  'Dominic Roberts',
#  'Sadie Grace Shelburne',
#  'Mia Sherrod',
#  'Kara Komarnitsky',
#  'Jennifer Oehlwein',
#  'Lexi Gray',
#  'Mel Guerra',
#  'Anna Aliau Guerra',
#  'Sarah Hladky',
#  'Duncan Oldham',
#  'Hayden Rivas',
#  'Alexandra Light',
#  'Stella Schwartz',
#  'Killeg Torres',
#  'Aimara Torrez',
#  'Hannah MacKenzie-Margulies',
#  'Amina Lydia Vargas',
#  'Bella Donatelli',
#  'Liana Wise',
#  'Lana Zecchino',
#  'Philip Gabriel Perez',
#  'Sophia Sowinski',
#  'Kayla Laufer',
#  'Shane Larson',
#  'Eliana Balzano',
#  'Jason Brickman',
#  'Christopher Knowlton',
#  'Victoria Gonzalez',
#  'Mary John Frank',
#  'Daniel Mai Morimoto',
#  'Doris Hering',
#  'Ivor Guest',
#  'Jack Mitchell',
#  'Daniel Nagrin',
#  'Trisha Brown',
#  'Sol Schwartz',
#  'David Vaughan',
#  'Emile Jaques-Dalcroze',
#  'Larry Billman',
#  'Frankie Manning',
#  'Clive Barnes',
#  'Murray Louis',
#  'Irina Baronova',
#  'Matteo',
#  'Betty Poindexter',
#  'Perces, Marjorie',
#  'Dassie Hoffman',
#  'Donald McKayle',
#  'John Van Lund',
#  'Marina Svetlova',
#  'Donald Saddler',
#  'Jimmy Slyde',
#  'Mary Anthony',
#  'Jocelyn Vollmar',
#  'Ivan Chermayeff',
#  'Irene Hunter',
#  'Ivan Nagy',
#  'Pina Bausch',
#  'Seymour Robins',
#  'Robert Rauschenberg',
#  'Lone Isaksen',
#  'Annabelle Lyon',
#  'Forrest Coggan',
#  'Rosella Hightower',
#  ...]

# %%
# grabbing all companies entities as well as individuals entities

companies_names = find_all_entities("organization")
entities_names = find_all_entities("individual")

# %%
print(companies_names)
# Out:
# ['American Dance Therapy Association', 'Dance Heritage Coalition', 'American Dance Festival', 'Sir Isaac Pitman &amp; Sons, Ltd.', 'Ballet National De Espana', 'Eine Ausstellung des U. S. Informationsdienstes', 'American Square Dance Society', 'Chicago Dance Coalition', 'Sasaki Associates', 'Acadmie Des Sciences De Bulgarie', 'Dance/USA', "Association Francaise d'Action Artistique", 'Denig Design Associates', "Jacob's Pillow Dance Festival", 'Blue Mountain Arts Collection', 'Dance Films Association, Inc.', 'Victor Talking Machine Company', 'National Endowment for the Arts', 'Kaplan, Barbara Paige', 'American Council for the Arts', 'Academy of Dance on Film', 'Melvin Ballou Gilbert', 'American Association of Museums', 'American Theatre Planning Board, Inc.', "Theatre National de l'Opera de Paris", 'New York City Ballet', 'Le Concours Choregraphique International de Bagnolet', 'Language of Dance Center', 'Language of Dance Association', 'Dana Press', 'Harwood Academic Publishers', 'Alexandra Tomalonis', 'National Dance Education Organization', 'Princeton Periodicals Inc.', 'Society for the Study of Myth and Tradition', 'Urban Bush Women', 'Bridgman Packer Dance', 'Reggie Wilson/Fist & Heel Performance Group', 'Lyon Opera Ballet', 'Wally Cardona Company', 'Ralph Lemon Company', 'National Song and Dance Company of Mozambique', 'American Ballet Theatre', 'Ximenes-Vargas Company', 'White Oak Dance Project', 'Zaccho Dance Theatre', 'Western Theatre Ballet', 'Buglisi/Foreman Dance', 'Ballet Hispanico', 'MoveOpolis', 'Metropolitan Opera Ballet', 'Paul Taylor Dance Company', 'Parsons Dance Company', 'ASzURe & Artists', 'Bad Boys of Dance', 'Danish Dance Theatre', 'Ballet Russe de Monte Carlo', 'Grupo Corpo', 'San Francisco Ballet', 'Limon Dance Company', 'Joffrey Ballet', 'Second Hand Dance Company', 'Conneticut Regional Ballet Company', 'Fort Lauderdale Ballet Company', 'Murray Louis Dance Company', 'Video Production Crew', 'Harrison and Fisher', "Jacob's Pillow Dancers", 'John Butler Dance Theatre', 'American Mime Theatre', 'Ballet Rambert', 'Donald McKayle &amp; Company', 'Santa Fe Opera Ballet', 'Boston Ballet', 'Royal Winnipeg Ballet', 'Los Duendes de Espana', 'Dance Theatre of Harlem', 'Berkshire Civic Ballet', 'Dayton Ballet Company', 'New Jersey Ballet Company', 'Cincinnati Ballet Company', 'Milwaukee Ballet Company', 'Ohio Ballet', 'Hartford Ballet', 'Joyce Trisler Danscompany', 'Berkshire Ballet', 'Houston Ballet', 'Washington Ballet', 'Lar Lubovitch Dance Company', 'Erica Drew Dance Company', 'Kineticompany', 'Danny Sloan Dance Company', 'Synapse Dance Theatre', 'Clive Thompson Dance Company', 'Batsheva Dance Company', 'The Blind Boys of Alabama', 'The Wondertwins', 'Abaca String Band', '48nord', 'The Beastie Boys', 'The Beatles', 'Human Mesh Dance', 'Calexico', 'Circa', 'David Dorfman Dance', 'Decadancetheatre', 'Ahn Trio', 'The Chi-Lites', 'Balkan Beat Box', 'Wire Monkey Dance', 'Shirley & Company', 'Deathprod', 'Boston Camerata', 'Bafonfo Tango Club', 'Rubberbandance Group', 'Compania Nacional de Danza (CND)', 'Chicago Mass Choir', 'Afro Celt Sound System', 'Dead Can Dance', 'Devo', 'The Chieftains', '33 Fainting Spells', 'Los Activos', 'The Clam Diggers/Lad Lane', 'Tribal Ethno Dance', 'Bang on a Can', 'Radolfo Baigi Ochestra Company', 'Bob Wills and his Texas Playboys', 'Somewhere Citylights', 'Ballethnic Dance Company', 'The Pan Caribbean Dancers', 'The Andrews Sisters', "The JB's (James Brown's Band)", 'Bang on a Can All-Stars', 'Music Antiqua', 'Teatro de Baile Espanol', 'Ellen Sinopoli Dance Company', 'Rose Marie and Charles Flachs', 'aboutDANCE', 'Capital Ballet Company', 'Tina Baird &amp; Lynn Schwabb', 'Coro Rociero de la Hermandad de Sevilla', 'Curubande Dance Company', 'Muntu Dance Theatre', 'The Bothy Band', 'Everett Dance Theatre', 'Laneville-Johnson Union Brass Band', 'Rhythm in Shoes', 'The Dave Brubeck Quartet', 'Boston Ballet II', 'Fred Darsow Dance Company', 'Philadanco', 'Zenon Dance Company', 'Steps Ahe ...

# %%
print(entities_names)
# Out:
# ['Canner, Norma', 'Silbermann, Alphons', 'Lucy Venable', 'Fred Berk', 'Kostrovitskaya, Vera S.', 'Walter Terry', 'Rennert, Jack', 'Baer, Nancy Van Norman', 'George Balanchine', 'Mason, Francis', 'Dominic, Zoe', 'Winkler-Betzendahl, Madeline', 'Duke University', 'Levine, Mindy', 'Whang, Vanessa', 'Yaniv Cohen', 'Doris Hering', 'Chailley, Jacques', 'Clement Crisp', 'Sainsbury, Anya', 'Williams, Peter', 'Merica Briffa', 'Jane Sherman', 'Archer, Cathaline Alford', 'Mitchell J. Mulholland', 'Brahms, Caryl', 'Simon, S.J.', 'The Museum of Broadcasting', 'Wiley, Roland John', 'Ken Mandelbaum', 'Hartnoll, Phyllis', 'Margot Fonteyn', 'Ortegel, Sister Adelaide', 'Holly Brubach', 'Annie Leibovitz', 'G.B.L. Wilson', 'Gay Morris', 'Menuhin, Diana Gould', 'Hartley, Lee Ann', 'Hayes, Elizabeth R.', 'Scoville, Jon', 'White, Kenneth', 'Preston, Valerie F.L.G', 'Hagood, Thomas K.', 'Macfall, Haldane', 'Ann Hutchinson Guest', 'Freedley, George', 'Reeves, John A.', 'Mary Grace Swift', 'Fait, Hollis F.', 'Shaw, John H.', 'Fox, Grace I.', 'Hollingsworth, Cecil B.', 'Barrow, Billie', 'Gates, Alice A.', 'Mark Edward Perugini', 'Landels, Willie', 'Wiseman, Carter', 'Latchaw and Pyatt', 'Steven Louis Shelley', 'Lois Ellfeldt', 'Dell, Cecily', 'Cyril W. Beaumont', 'DeNatale, Douglas', 'Ito, Karen L.', 'Grout, Donald Jay', 'Emmerson, George S.', 'Nagler, A. M.', 'Fitzgibbon, Cecelia', 'Mourinho, Jnior', 'Rodrigues, Antnio', 'Hutcheon, Linda', 'Taylor, Margaret Fisk', 'Katherine Dunham', 'Fuller, Anna', "O'Moore, Mary", 'Pisk, Litz', 'Rich, Barbara', 'Polin, Jane', 'Marcus, Stephen', 'Sikes, Toni Fountain', 'Ivor Guest', 'Reinhart, Stephanie', 'Buckle, Richard', 'Van Gelder, Naneene', 'Ellison, Deborah', 'Stanforth, Dixie', 'IDEA Foundation', 'Sorenson, Jacki', 'Bruns, Bill', 'Harris, Ron', 'Souriau, Paul', 'Geoffrey Gorer', 'Michel Huet', 'Claude Savary', 'National Museum of American History', 'David Levinson', 'Robert Farris Thompson', 'Kariamu Welsh', 'Tracey, Hugh', 'Harnan, Terry', 'Hight, Gladys', 'Arlene Croce', 'Nectoux, Jean-Michel', 'Gherman, Beverly', 'Kpacobckar, B.', 'Robert Tracy', 'Whitehead, Alfred North', 'Lois Greenfield', 'Jacques Ranciere', 'Albert, Gennady', 'Leibowitz, Judith', 'Connington, Bill', 'Barlow, Wilfred', 'Twysden, A. E.', 'Steendrukkerij de Jong &amp; Co.', 'De Gamez, Tana', 'Siegel, Beatrice', 'Hall, A. George', 'Ramsay Burt', 'Rockwell, John', 'Gottfried, Martin', 'Teachout, Terry', 'Springer, John', 'Muna, RJ', 'Alonzo King', 'Stepanov, V. I.', 'Pinkney, Andrea Davis', 'Jennifer Dunning', 'Jack Mitchell', 'Cook, Susan', 'Joseph H. Mazo', 'Friedman, Lise', 'Brassel, Robert', 'Nancy Ellison', 'John Martin', 'Payne, Charles', 'Barker, Barbara Mackin', 'Olga Maynard', 'Reiter, Susan', 'Jack Anderson', 'The National Task Force On Presenting And Touring The Performing Arts', 'Carolyn Adams', 'Julie Adams Strandberg', 'Livingston, Lili Cockerille', 'Evans, Bessie', 'Evans, May G.', 'Gus Giordano', 'Virgil Thomson', 'Matlaw, Myron', 'Stein, Charles W.', 'Mates, Julian', 'Mawson, Thomas H.', 'Gibbon, Monk', 'Stephenson, Roberta Martin', 'Barham, Jerry N.', 'Thomas, William L.', 'Celia Sparger', 'Heckler, Richard Strozzi', 'Du Solier, W.', 'Reed, Carlynn', 'Intravaia, Toni', 'Villanua, Lolita', 'Joan Acocella', 'Lynn Garafola', 'Lonsdale, Steven', 'Connor, Jim', 'Ann Reinking', 'Quinlan, Kathleen', 'Naslund, Erik', 'Janice Ross', 'Jane Pritchard', 'Svetloff, V.', 'Levine, Ellen', 'Money, Keith', 'Dandre, V.', 'Warren, Larry', 'Marian Van Tuyl', 'Royce, Anya Peterson', 'Maurice Emmanuel', 'Jones, Kristin', 'Ginzel, Andrew', 'Gyenes', 'Rita Vega de Triana', 'Bliss, Mark B.', 'Homans, Jennifer', 'De Lauze, F.', 'Heppenstall, Rayner', 'Thistle, Donald', 'Lihs, Harriet R.', 'Franks, A. H.', 'Benjamin, Ben E.', 'Voorsanger, Catherine Hoover', 'K. Howat, John', 'Mikhail Baryshnikov', 'Edwards, Harvey', 'Jenyns, Soame', 'Pohren, D. E.', 'Hill, Camille Long', 'Strenkovsky, Serge', 'Doris Humphrey', 'Mawer, Irene', 'Albertieri, Luigi', 'Fi ...

# %% [markdown]
# Checking out to see whether there's an intersection between entities names and companies names
#
# It is much common for companies entities to be submitted as individual entities by mistakes

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

print(intersection(entities_names, companies_names))
# Out:
# ['Ballet Theatre', "Lotte Goslar's Pantomime Circus", 'Bob Berky', 'Donald Byrd', 'Beppie Blankert', 'Ryoko Kudo', 'Billy Tipton Memorial Saxophone Quartet', 'Earnest T. Morgan', 'Rosy Co', 'Mia Michaels', 'Airjazz', 'Kathy Rose', 'Pink Inc.', 'Indo-American Dance Group', 'Manhattan Festival Ballet', 'The National Ballet', 'Batoto Yetu', 'CoisCeim Dance Theatre', 'Harkness Ballet', 'Toronto Dance Theatre', 'Bludance Theatre', 'Merry-Go-Rounders', 'Pittsburgh Ballet Theatre', 'Les Ballet Jazz De Montreal', 'Complexions Contemporary Ballet', 'Tania Perez-Salas Compania De Danza', 'Groupe Emile Dubois', 'Cantarella School of Dance']

# %%
# saving all entities name
pickle.dump(entities_names, open("all_indivs.pickle", 'wb')) 
pickle.dump(companies_names, open("all_comps.pickle", 'wb'))
